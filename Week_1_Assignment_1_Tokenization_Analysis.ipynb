# %% [markdown]
# # Week 1 Assignment 1 | Tokenization Analysis
#
# **Objective:** Analyze how GPT-4's tokenizer handles a non-English text compared to its English translation, quantifying the "multilingual tax" and identifying tokenizer bias.
#
# ---
#
# ## Step 1: Select Source Text
#
# Choose a non-English paragraph (100-150 words) from a news article, Wikipedia entry, or literary text.

# %% [markdown]
# ### Original Non-English Text
#
# **Language:** [Specify language]
#
# **Source:** [Cite source]
#
# **Text:**
# ```
# [Paste your original text here]
# ```

# %% [markdown]
# ---
#
# ## Step 2: English Translation
#
# Provide or find an English translation of the same paragraph.

# %% [markdown]
# ### English Translation
#
# **Text:**
# ```
# [Paste your English translation here]
# ```

# %% [markdown]
# ---
#
# ## Step 3: Tokenize Using GPT-4 Tokenizer
#
# Use the [Tokenizer Comparison demo](https://platform.openai.com/tokenizer) to tokenize both texts.

# %%
# Record your token counts from the demo

# Non-English token count
non_english_tokens = None  # Replace with actual count from demo
non_english_language = ""  # Specify language

# English token count
english_tokens = None  # Replace with actual count from demo

print(f"Non-English ({non_english_language}) Token Count: {non_english_tokens}")
print(f"English Token Count: {english_tokens}")

# %% [markdown]
# ### Screenshots from Tokenizer Demo
#
# **Screenshot 1: Non-English Tokenization**
#
# [Insert screenshot here or describe the tokenization]
#
# **Screenshot 2: English Tokenization**
#
# [Insert screenshot here or describe the tokenization]

# %% [markdown]
# ---
#
# ## Step 4: Calculate the Multilingual Tax

# %%
# Calculate multilingual tax ratio
multilingual_tax = non_english_tokens / english_tokens

print(f"Multilingual Tax Ratio: {multilingual_tax:.2f}")
print(f"\nInterpretation:")
print(f"- For every 1 token in English, the {non_english_language} version uses {multilingual_tax:.2f} tokens")
print(f"- Overhead: {(multilingual_tax - 1) * 100:.1f}% more tokens in {non_english_language}")

# %% [markdown]
# ---
#
# ## Step 5: Identify Tokenizer Bias - Three Specific Examples
#
# Find three specific words/phrases that demonstrate tokenizer bias (where the non-English version fragments into more tokens than the English equivalent).

# %% [markdown]
# ### Example 1: Word Fragmentation
#
# **Non-English Word:** [word]
#
# **Tokens:** [number] tokens
#
# **English Equivalent:** [word]
#
# **Tokens:** [number] tokens
#
# **Observation:** [Explain why this reveals bias]

# %% [markdown]
# ### Example 2: Word Fragmentation
#
# **Non-English Word:** [word]
#
# **Tokens:** [number] tokens
#
# **English Equivalent:** [word]
#
# **Tokens:** [number] tokens
#
# **Observation:** [Explain why this reveals bias]

# %% [markdown]
# ### Example 3: Word Fragmentation
#
# **Non-English Word:** [word]
#
# **Tokens:** [number] tokens
#
# **English Equivalent:** [word]
#
# **Tokens:** [number] tokens
#
# **Observation:** [Explain why this reveals bias]

# %% [markdown]
# ---
#
# ## Step 6: Analysis & Practical Implications
#
# ### What the Results Mean

# %% [markdown]
# #### Cost Implications
#
# **Analysis:**
#
# [Explain the financial impact of the multilingual tax. For example:
# - If English users pay $X per 1K tokens, how much more would non-English users pay?
# - What does this mean for global product equity?]
#
# **Example Calculation:**
# ```
# If English costs $0.01 per 1K tokens:
# - English: 100 tokens → $0.001
# - Non-English: 100 * [ratio] tokens → $[cost]
# - Cost difference: [percentage]%
# ```

# %% [markdown]
# #### Context Window Efficiency
#
# **Analysis:**
#
# [Explain how tokenizer bias affects context window planning:
# - A model with 4K context window can fit ~[X] English words vs ~[Y] non-English words
# - What content gets truncated?
# - How does this affect user experience?]

# %% [markdown]
# #### Product Design Implications
#
# **Key Considerations:**
#
# 1. **Feature Parity:** Do you need special UI to warn non-English users about token limits?
#
# 2. **Model Selection:** Should you recommend different models to different language users?
#
# 3. **Pricing Strategy:** Should multilingual support cost more, less, or the same?
#
# 4. **Performance Expectations:** How do you set realistic expectations for non-English users?

# %% [markdown]
# ---
#
# ## Step 7: Summary & Conclusions

# %% [markdown]
# ### Key Findings
#
# - **Multilingual Tax:** [Your ratio]x (or [Your percentage]% overhead)
#
# - **Primary Bias Patterns:** [Describe 2-3 key patterns you discovered]
#
# - **Business Impact:** [1-2 sentences on the practical implications]
#
# ### Recommendations for Real-World Implementation
#
# [Write 3-4 bullet points on how you'd handle this if building a product for this language:]

# %% [markdown]
# ---
#
# ## References
#
# - [Tokenizer Comparison Demo](https://platform.openai.com/tokenizer)
# - Source text: [Link/citation]
# - Translation source: [Link/citation if applicable]
